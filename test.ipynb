# %%
import tushare as ts
ts.set_token('bc635143344483cee2e990d64c8d356a6f50f5786e6918ff7001b524')
pro = ts.pro_api()
#df = pro.moneyflow_ths(ts_code='002149.SZ', start_date='20241001', end_date='20241011')
df = pro.moneyflow(ts_code='002149.SZ', start_date='20190115', end_date='20190315')

df
# Out:
#       ts_code trade_date  buy_sm_vol  buy_sm_amount  sell_sm_vol  \
# 0   002149.SZ   20190315      114879       10107.09        93962
# 1   002149.SZ   20190314      186298       16666.45       153324
# 2   002149.SZ   20190313      164462       14348.54       134517
# 3   002149.SZ   20190312       61842        5018.00        50762
# 4   002149.SZ   20190311       49084        3907.86        45077
# 5   002149.SZ   20190308       94247        7582.36        62412
# 6   002149.SZ   20190307       87999        7299.04        87481
# 7   002149.SZ   20190306       96110        7717.74        82379
# 8   002149.SZ   20190305      134405       10812.88       103186
# 9   002149.SZ   20190304       84576        6606.20       118130
# 10  002149.SZ   20190301       36978        2685.17        34322
# 11  002149.SZ   20190228       46028        3338.00        36629
# 12  002149.SZ   20190227       92685        6852.70        62007
# ...

# %%
df = pro.index_basic(ts_code='881279.TI')
df
# Out:
# Empty DataFrame
# Columns: [ts_code, name, market, publisher, category, base_date, base_point, list_date]
# Index: []

# %%
#获取单日全部股票数据
df = pro.moneyflow(trade_date='20190315')#获取单日全部股票数据
df
# Out:
#         ts_code trade_date  buy_sm_vol  buy_sm_amount  sell_sm_vol  \
# 0     000779.SZ   20190315       11377        1150.17        11100
# 1     000933.SZ   20190315       94220        4803.22       105924
# 2     002270.SZ   20190315       43979        2330.96        45893
# 3     002319.SZ   20190315       21502        2952.88        17155
# 4     002604.SZ   20190315       31944         607.35        58667
# ...         ...        ...         ...            ...          ...
# 3569  601500.SH   20190315       13150         974.74        12389
# 3570  000517.SZ   20190315       95373        2866.43       109931
# 3571  600784.SH   20190315       34356        2033.67        29840
# 3572  603017.SH   20190315       25325        3770.17        23766
# 3573  000802.SZ   20190315       38425        4920.03        35148
#
#       sell_sm_amount  buy_md_vol  buy_md_amount  sell_md_vol  sell_md_amount  \
# 0            1122.97       13012        1316.72        14812         1498.90
# ...
